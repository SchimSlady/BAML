# %% [markdown]
# ### Oktoberfest Beer Data

# %%
# Imports
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# a) Read the data from *visitors.csv* into a pandas dataframe.

# %%
visitors = pd.read_csv('visitors.csv')

# %% [markdown]
# b) Take a look at the dataframe's column names. Display the ten top rows of the dataframes.

# %%
print(visitors.columns)
visitors.head(10)
# Out:
# Index(['Year', 'Visitors (million)', 'Beer consumption (million liters)'], dtype='object')
#    Year  Visitors (million)  Beer consumption (million liters)
# 0  2024                 6.7                                7.0
# 1  2023                 7.2                                7.2
# 2  2022                 5.7                                5.6
# 3  2019                 6.3                                7.3
# 4  2018                 6.3                                7.5
# 5  2017                 6.2                                7.5
# 6  2016                 5.6                                6.6
# 7  2015                 5.9                                7.3
# 8  2014                 6.3                                7.7
# 9  2013                 6.4                                6.7

# %% [markdown]
# c) Select and display only the column of visitors (... only the fifth row of your dataframe).

# %%
print(visitors['Visitors (million)']) #Visitors column
print(visitors.iloc[4]) #fifth row
# Out:
# 0     6.7
# 1     7.2
# 2     5.7
# 3     6.3
# 4     6.3
# 5     6.2
# 6     5.6
# 7     5.9
# 8     6.3
# 9     6.4
# 10    6.4
# 11    6.9
# 12    6.4
# 13    5.7
# 14    6.0
# 15    6.2
# 16    6.5
# 17    6.1
# 18    5.9
# 19    6.3
# 20    5.9
# 21    5.5
# 22    6.9
# 23    6.5
# 24    6.5
# 25    6.4
# 26    6.9
# 27    6.7
# 28    6.6
# 29    6.5
# 30    5.9
# 31    6.4
# 32    6.7
# 33    6.2
# 34    5.7
# 35    6.5
# 36    6.7
# 37    7.1
# 38    7.0
# 39    6.6
# 40    5.8
# 41    6.2
# 42    5.1
# Name: Visitors (million), dtype: float64
# Year                                 2018.0
# Visitors (million)                      6.3
# Beer consumption (million liters)       7.5
# Name: 4, dtype: float64

# %% [markdown]
# d) How many visitors were there in 1995?

# %%
x = visitors.loc[visitors['Year'] == 1995, 'Visitors (million)']
print(x)
# Out:
# 27    6.7
# Name: Visitors (million), dtype: float64

# %% [markdown]
# e) What is the value range of the attribute "Beer consumption (million liters)"?

# %%
max = visitors['Beer consumption (million liters)'].max()
min = visitors['Beer consumption (million liters)'].min()
Range = max - min
print("Range Beer Consumption (million liters):", Range)
# Out:
# Range Beer Consumption (million liters): 3.8600000000000003

# %% [markdown]
# f) What was the year with the greatest beer consumption? How much beer was consumed?

# %%
row = visitors["Beer consumption (million liters)"].argmax()
print (visitors.iloc[row])
# Out:
# Year                                 2014.0
# Visitors (million)                      6.3
# Beer consumption (million liters)       7.7
# Name: 8, dtype: float64

# %% [markdown]
# g) Plot the beer consumption over the years. Turn on the grid of your plot.

# %%
visitors.plot('Year', 'Beer consumption (million liters)')
plt.grid()

# %% [markdown]
# h) Compute the correlation matrix of the dataframe. Which conclusions can you draw?

# %%
visitors.corr()
# Out:
#                                        Year  Visitors (million)  \
# Year                               1.000000           -0.029103
# Visitors (million)                -0.029103            1.000000
# Beer consumption (million liters)  0.869266            0.188244
#
#                                    Beer consumption (million liters)
# Year                                                        0.869266
# Visitors (million)                                          0.188244
# Beer consumption (million liters)                           1.000000

# %% [markdown]
# i) Load the data from *beer_price.csv* into a second dataframe. Then merge the two dataframes based on the year with an outer join.
# Observe which values you get for years that are not listed in some of the data sets.

# %%
price = pd.read_csv('beer_price.csv')
merged = pd.merge(visitors, price, on='Year', how='outer')
merged
# Out:
#     Year  Visitors (million)  Beer consumption (million liters)  Min price  \
# 0   1971                 NaN                                NaN       2.50
# 1   1972                 NaN                                NaN       2.60
# 2   1973                 NaN                                NaN       2.90
# 3   1974                 NaN                                NaN       3.20
# 4   1975                 NaN                                NaN       3.50
# 5   1976                 NaN                                NaN       3.70
# 6   1977                 NaN                                NaN       4.10
# 7   1978                 NaN                                NaN       4.10
# 8   1979                 NaN                                NaN       4.55
# 9   1980                 5.1                               3.84       4.80
# 10  1981                 6.2                               4.24       4.80
# 11  1982                 5.8                               4.33       5.25
# 12  1983                 6.6                               4.58       5.60
# 13  1984                 7.0                               4.97       5.75
# 14  1985                 7.1                               5.45       5.90
# 15  1986                 6.7                               5.38       6.10
# 16  1987                 6.5                               5.28       6.35
# 17  1988                 5.7                               5.10       6.60
# 18  1989                 6.2                               5.12       6.70
# 19  1990                 6.7                               5.43       6.95
# 20  1991                 6.4                               5.47       7.40
# 21  1992                 5.9                               4.89       8.10
# 22  1993                 6.5                               5.19       8.80
# 23  1994                 6.6                               5.21       9.00
# 24  1995                 6.7                               5.02       9.50
# 25  1996                 6.9                               5.26       9.80
# 26  1997                 6.4                               5.59      10.20
# 27  1998                 6.5                               5.48      10.40
# 28  1999                 6.5                               6.00      10.70
# 29  2000                 6.9                               6.46      11.20
# 30  2001                 5.5                               4.87      11.70
# 31  2002                 5.9                               5.76       6.30
# 32  2003                 6.3                               6.23       6.30
# 33  2004                 5.9                               6.12       6.70
# 34  2005                 6.1                               6.10       6.80
# 35  2006                 6.5                               6.86       6.95
# 36  2007                 6.2                               6.94       7.30
# 37  2008                 6.0                               6.49       7.80
# 38  2009                 5.7                               6.50       8.10
# 39  2010                 6.4                               7.00       8.30
# 40  2011                 6.9                               7.50       8.70
# 41  2012                 6.4                               7.40       9.10
# 42  2013                 6.4                               6.70       9.40
# 43  2014                 6.3                               7.70       9.70
# 44  2015                 5.9                               7.30      10.10
# 45  2016                 5.6                               6.60      10.40
# 46  2017                 6.2                               7.50      10.60
# 47  2018                 6.3                               7.50      10.70
# 48  2019                 6.3                               7.30      10.80
# 49  2022                 5.7                               5.60      12.60
# 50  2023                 7.2                               7.20      12.60
# 51  2024                 6.7                               7.00      13.60
#
#     Max price
# 0        2.95
# 1        3.05
# 2        3.25
# 3        3.50
# 4        3.75
# 5        3.95
# 6        4.25
# 7        4.35
# 8        4.65
# 9        4.90
# 10       5.25
# 11       5.60
# 12       5.90
# 13       6.00
# 14       6.30
# 15       6.50
# 16       6.65
# 17       6.85
# 18       7.20
# 19       7.55
# 20       8.50
# 21       8.85
# 22       9.45
# 23       9.80
# 24      10.40
# 25      10.50
# 26      10.90
# 27      11.30
# 28      11.80
# 29      12.60
# 30      12.80
# 31       6.80
# 32       6.80
# 33       7.10
# 34       7.25
# 35       7.50
# 36       7.90
# 37       8.30
# 38       8.60
# 39       8.90
# 40       9.20
# 41       9.50
# 42       9.85
# 43      10.10
# 44      10.35
# 45      10.70
# 46      10.95
# 47      11.50
# 48      11.80
# 49      13.80
# 50      14.90
# 51      15.30

# %% [markdown]
# j) Until 2001, the beer price is reported in DEM ("Deutsche Mark"), the former German currency.
# Adjust the beer prices (min and max) to give values in EUR.
# You may assume that 1 EUR = 1.95583 DEM.

# %%
def DMtoEUR(DM):
    EUR = DM / 1.95583
    return EUR

merged.loc[merged['Year'] <= 2001, 'Min price'] = DMtoEUR(merged.loc[merged['Year'] <= 2001, 'Min price'])

merged.loc[merged['Year'] <= 2001, 'Max price'] = DMtoEUR(merged.loc[merged['Year'] <= 2001, 'Max price'])

merged
# Out:
#     Year  Visitors (million)  Beer consumption (million liters)  Min price  \
# 0   1971                 NaN                                NaN   1.278230
# 1   1972                 NaN                                NaN   1.329359
# 2   1973                 NaN                                NaN   1.482746
# 3   1974                 NaN                                NaN   1.636134
# 4   1975                 NaN                                NaN   1.789522
# 5   1976                 NaN                                NaN   1.891780
# 6   1977                 NaN                                NaN   2.096297
# 7   1978                 NaN                                NaN   2.096297
# 8   1979                 NaN                                NaN   2.326378
# 9   1980                 5.1                               3.84   2.454201
# 10  1981                 6.2                               4.24   2.454201
# 11  1982                 5.8                               4.33   2.684282
# 12  1983                 6.6                               4.58   2.863235
# 13  1984                 7.0                               4.97   2.939928
# 14  1985                 7.1                               5.45   3.016622
# 15  1986                 6.7                               5.38   3.118880
# 16  1987                 6.5                               5.28   3.246703
# 17  1988                 5.7                               5.10   3.374526
# 18  1989                 6.2                               5.12   3.425656
# 19  1990                 6.7                               5.43   3.553479
# 20  1991                 6.4                               5.47   3.783560
# 21  1992                 5.9                               4.89   4.141464
# 22  1993                 6.5                               5.19   4.499369
# 23  1994                 6.6                               5.21   4.601627
# 24  1995                 6.7                               5.02   4.857273
# 25  1996                 6.9                               5.26   5.010660
# 26  1997                 6.4                               5.59   5.215177
# 27  1998                 6.5                               5.48   5.317436
# 28  1999                 6.5                               6.00   5.470823
# 29  2000                 6.9                               6.46   5.726469
# 30  2001                 5.5                               4.87   5.982115
# 31  2002                 5.9                               5.76   6.300000
# 32  2003                 6.3                               6.23   6.300000
# 33  2004                 5.9                               6.12   6.700000
# 34  2005                 6.1                               6.10   6.800000
# 35  2006                 6.5                               6.86   6.950000
# 36  2007                 6.2                               6.94   7.300000
# 37  2008                 6.0                               6.49   7.800000
# 38  2009                 5.7                               6.50   8.100000
# 39  2010                 6.4                               7.00   8.300000
# 40  2011                 6.9                               7.50   8.700000
# 41  2012                 6.4                               7.40   9.100000
# 42  2013                 6.4                               6.70   9.400000
# 43  2014                 6.3                               7.70   9.700000
# 44  2015                 5.9                               7.30  10.100000
# 45  2016                 5.6                               6.60  10.400000
# 46  2017                 6.2                               7.50  10.600000
# 47  2018                 6.3                               7.50  10.700000
# 48  2019                 6.3                               7.30  10.800000
# 49  2022                 5.7                               5.60  12.600000
# 50  2023                 7.2                               7.20  12.600000
# 51  2024                 6.7                               7.00  13.600000
#
#     Max price
# 0    1.508311
# 1    1.559440
# 2    1.661699
# 3    1.789522
# 4    1.917345
# 5    2.019603
# 6    2.172990
# 7    2.224120
# 8    2.377507
# 9    2.505330
# 10   2.684282
# 11   2.863235
# 12   3.016622
# 13   3.067751
# 14   3.221139
# 15   3.323397
# 16   3.400091
# 17   3.502349
# 18   3.681302
# 19   3.860254
# 20   4.345981
# 21   4.524933
# 22   4.831708
# 23   5.010660
# 24   5.317436
# 25   5.368565
# 26   5.573082
# 27   5.777598
# 28   6.033244
# 29   6.442278
# 30   6.544536
# 31   6.800000
# 32   6.800000
# 33   7.100000
# 34   7.250000
# 35   7.500000
# 36   7.900000
# 37   8.300000
# 38   8.600000
# 39   8.900000
# 40   9.200000
# 41   9.500000
# 42   9.850000
# 43  10.100000
# 44  10.350000
# 45  10.700000
# 46  10.950000
# 47  11.500000
# 48  11.800000
# 49  13.800000
# 50  14.900000
# 51  15.300000

# %% [markdown]
# k) Compute the mean and variance of "Min price" during the period from 2000 to 2007.

# %%
mask = (2000 <= merged['Year']) & (merged['Year'] <= 2007)

mean = merged[mask]['Min price'].mean()
var = merged[mask]['Min price'].var()

print('Mean:', mean)
print('Var:', var)
# Out:
# Mean: 6.507323009924175
# Var: 0.27408942166792033

# %% [markdown]
# l) Add a new column to the merged dataframe, describing the relative difference in beer prices
# between two consecutive years in percent. Plot this difference against "Year".

# %%
merged ['Price Increase'] = (
    (merged["Min price"] - merged["Min price"].shift(1))
    / merged["Min price"]
    * 100
)

merged.plot('Year', 'Price Increase')
# Out:
# <Axes: xlabel='Year'>

# %% [markdown]
# m) Create a bar plot displaying the minimum and maximum prices over the years.

# %%
merged.plot(x='Year', y= ['Min price', 'Max price'], kind='bar')
# Out:
# <Axes: xlabel='Year'>

# %% [markdown]
# n) Compute estimates (lower and upper bound) of the beer revenue and visualize them by bar plot.

# %%
merged ['Beer revenue lB (in Million)'] = (merged['Beer consumption (million liters)'] * merged['Min price'] )
merged ['Beer revenue uB (in Million)'] = (merged['Beer consumption (million liters)'] * merged['Max price'] )

merged.tail(10)
#merged.plot.bar(x = 'Year', y=['Beer revenue lB', 'Beer revenue uB'])
# Out:
#     Year  Visitors (million)  Beer consumption (million liters)  Min price  \
# 42  2013                 6.4                                6.7        9.4
# 43  2014                 6.3                                7.7        9.7
# 44  2015                 5.9                                7.3       10.1
# 45  2016                 5.6                                6.6       10.4
# 46  2017                 6.2                                7.5       10.6
# 47  2018                 6.3                                7.5       10.7
# 48  2019                 6.3                                7.3       10.8
# 49  2022                 5.7                                5.6       12.6
# 50  2023                 7.2                                7.2       12.6
# 51  2024                 6.7                                7.0       13.6
#
#     Max price  Price Increase  Beer revenue lB  Beer revenue uB  \
# 42       9.85        3.191489       62980000.0       65995000.0
# 43      10.10        3.092784       74690000.0       77770000.0
# 44      10.35        3.960396       73730000.0       75555000.0
# 45      10.70        2.884615       68640000.0       70620000.0
# 46      10.95        1.886792       79500000.0       82125000.0
# 47      11.50        0.934579       80250000.0       86250000.0
# 48      11.80        0.925926       78840000.0       86140000.0
# 49      13.80       14.285714       70560000.0       77280000.0
# 50      14.90        0.000000       90720000.0      107280000.0
# 51      15.30        7.352941       95200000.0      107100000.0
#
#     Beer revenue lB (in Million)  Beer revenue uB (in Million)
# 42                         62.98                        65.995
# 43                         74.69                        77.770
# 44                         73.73                        75.555
# 45                         68.64                        70.620
# 46                         79.50                        82.125
# 47                         80.25                        86.250
# 48                         78.84                        86.140
# 49                         70.56                        77.280
# 50                         90.72                       107.280
# 51                         95.20                       107.100
